# %% [markdown]
# # PubMed Topic Tracker
# ## 1. Search and download
#
# This tool allows to build PubMed queries, download entries, parse them and save them to a neat .csv file. It takes as input a PubMed query, and outputs a dataset (i.e: a folder containing a PubMed export, its metadata saved in the log file, and the Medline file for eventually importing the references you are analysing in Zotero or similar software).
#
# The output can be explored with the second and third notebooks of this collection.
#
# Dependencies:
# - pandas 1.2.1
# - IPython 7.19.0
# - tqdm 4.55.1
# - shutils 0.1.0

# %%
# Import libraries
from time import sleep
import PubGetParse as pg
import pandas as pd
import numpy as np
from IPython.display import clear_output
from tqdm import tqdm
import time
from collections import Counter
import re
import os
from shutil import copy2

# Define log file
log = "log.py"

# %%
# Log file
if os.path.exists(log):
    os.remove(log)
    open(log, 'w').close()
else:
    open(log, 'w').close()
timestr = time.strftime("%Y.%m.%d-%H:%M:%S")
with open(log, "w") as f:
    f.write("# This is a log file. It is saved as .py so that the following notebooks can easily import it and use its information.\n\n")
with open(log, "a") as f:
    f.write("# started at: " + timestr + "\n\n")

# %% [markdown]
# ## First step: definition and segmentation of the query
# The query must not contain time references. PubMed allows only max. 100k results per query, hence the main query will be splitted in years; e.g: if the time references are 1990 - 1995 the software will run one query for 1990, one for 1991, and so on up to 1995. Detailed information on the segmented queries are saved in the log for reproducibility.
#
# Every other PubMed tag can be used.

# %%
# Definition of the query. The best idea is to define it in PubMed and then copypaste it here.
print("Important: do not include timepoints in your query, they will be defined via this interface")
pubmed_query = input("Paste here your PubMed query:")
year0 = int(input("\nIn order to better manage the amount of results, the query will be segmented by year. \nFrom what year do you want to start?"))
year1 = int(input("Up to what year do you want to search?"))

x = range(year0, (year1 + 1) )
yearlist = []
for n in x:
    yearlist.append(n)
querylist = []
for x in yearlist:
    timequery = "\"" + str(x) + "/01/01" + "\"" + "[Date - Publication] : " + "\"" + str(x) + "/12/31" "\"" + "[Date - Publication]" + " AND " + pubmed_query
    querylist.append(timequery)

displayquery = "\"" + str(year0) + "/01/01" + "\"" + "[Date - Publication] : " + "\"" + str(year1) + "/12/31" "\"" + "[Date - Publication]" + " AND " + pubmed_query

# Add log
timestr = time.strftime("%Y.%m.%d-%H:%M:%S")
with open(log, "a") as f:
    f.write("year0 = " + "\"" +  str(year0) + "\"" + "\n")
    f.write("year1 = " + "\"" + str(year1) + "\"" + "\n")
    f.write("keywords = " + "\"" + pubmed_query + "\"" + "\n\n")
    f.write("'''\n")
    f.write("query = " + displayquery + "\n") 
    f.write("   Segmented as:\n")
    for x in querylist:
        f.write(x + "\n")
    f.write("'''\n\n")
print("\nThis query will be performed in PubMed, segmented by year:\n", displayquery)
# Out:
# Important: do not include timepoints in your query, they will be defined via this interface
#
# This query will be performed in PubMed, segmented by year:
#  "2021/01/01"[Date - Publication] : "2022/12/31"[Date - Publication] AND xml

# %%
# Run the queries (segmented by year) and merge all the PubMed IDs in one list
pids = []
for timequery in tqdm(querylist):
    x = pg.get_p_ids(timequery)
    pids.extend(x)
    sleep(0.3)
len1 = len(pids)

# Clean duplicates from list
pids = list(dict.fromkeys(pids))
len2 = len(pids)
dropped = len1-len2

print("Query completed. " + str(len1) + " PubMed IDs retrieved. " + str(dropped) + " duplicate entries dropped.\n ")
print("Downloading the non-duplicate entries, which are " + str(len2))
# Add log
timestr = time.strftime("%Y.%m.%d-%H:%M:%S")
with open(log, "a") as f:
    f.write("# Query executed at: " + timestr + "\n")
    f.write("paper_count_original = " + "\"" + str(len1) + "\"" + "\n")
estimatedtime = round((len2 / 1.5)/60, 2)
# Out:
# 100%|██████████| 2/2 [00:02<00:00,  1.24s/it]
# Query completed. 53 PubMed IDs retrieved. 2 duplicate entries dropped.
#
# Downloading the non-duplicate entries, which are 51

# %% [markdown]
# ## Retrieving MedLine entries for each one of the IDs and parsing them
# Here we pass every PubMed ID previously retrieved to the API. The API responds with the MEDLINE record, from which we parse and save what follows:
#
# pid, pid_type, year, journal, publisher, title, book_title, abstract, oabstract, authors, editors, language, meshterms, keywords, coi, doi

# %%
# Here we download every article and we parse it as a list

# Add log
timestr = time.strftime("%Y.%m.%d-%H:%M:%S")
with open(log, "a") as f:
    f.write("# Download started at: " + timestr + "\n")

estimatedtime = round((len(pids) / 1.5)/60, 2)
print("\n\nEstimated time for downloading and parsing: ", estimatedtime, "minutes. \nThis assumes 1.5 iterations per second.\nGo grab yourself a coffee ;)")

# Retrieve and parse entries
entrylist = []
for pid in tqdm(pids):
    x = pg.get_parse_article_re(pid)
    entrylist.append(x)
    sleep(0.3)#need to slow it down to avoid being kicked from the server, pity.

# Add log
timestr = time.strftime("%Y.%m.%d-%H:%M:%S")
with open(log, "a") as f:
    f.write("# Download finished at: " + timestr + "\n")
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# Estimated time for downloading and parsing:  0.57 minutes.
# This assumes 1.5 iterations per second.
# Go grab yourself a coffee ;)
# 100%|██████████| 51/51 [00:42<00:00,  1.19it/s]

# %% [markdown]
# ---
# ## MedLine entries become a neat dataframe
# Here we check for duplicates using PubMed IDs, we remove articles published outside the time interval specified in the query and create a dataframe with the content of every entry. We finally export it as a .csv file.
#
# ### Important: some cleaning is performed on the data
# PubMed saves multiple dates per entry and can include in the results papers published before the desired timepoint because they have been indexed, so added to the database, years later.
# Hence, to provide clean results, here we remove from the dataset the papers whose actual publication date was outside the scope of the query.

# %%
df = pd.DataFrame(entrylist, columns =[
    "p_id", "pid_type", "year", "journal", "publisher", "title", "book_title", "abstract", "oabstract", "authors", "editors", "language", "meshterms", "keywords", "coi", "grant", "doi"])
df.index += 1 

# Replace empty cells with NA and cast year to INT
df = df.replace(r'^\s*$', np.nan, regex=True)
df["year"] = df["year"].astype('float').astype('Int32')

# check time interval
lenght0 = len(df.index)
df = df.drop(df[df.year < int(year0)].index)
df = df.drop(df[df.year > int(year1)].index)
df = df.reset_index(drop=True)
df.index += 1
lenght1 = len(df.index)

message = ("Dropped " + str(lenght0-lenght1) + " entries due to publication time outside query parameters.")
print(message)
lenght2 = len(df.index)
message = (str(lenght2) + " entries included.")
print(message)

# Export the dataframe
timestr = time.strftime("%Y%m%d-%H%M%S")
exportdir = ("export/" + timestr)
os.mkdir(exportdir)
df.to_csv(exportdir + "/PubMed full records.csv",  sep=';')

print(str(len1) + " entries found. " + str(dropped) + " duplicate entries dropped.\n ")
print(str(len2) + " records successfully saved to .csv in " + exportdir + ". \nYou can go ahead with the analysis :)")
display(df.head(20))

# Add log
timestr = time.strftime("%Y.%m.%d-%H:%M:%S")
with open(log, "a") as f:
    f.write("paper_count_no_duplicates = " + "\"" + str(len(df)) + "\"" + "\n")
    f.write("# Data exported at: " + timestr + " to : " + exportdir + "\n")
    f.write("exportdir = " + "\"" + exportdir + "\"" + "\n")

# Copy the log file to the export folder as documentation
destination_log = exportdir + "/log.txt"
copy2(log, destination_log)
# Out:
# Dropped 0 entries due to publication time outside query parameters.
# 51 entries included.
# 53 entries found. 2 duplicate entries dropped.
#
# 51 records successfully saved to .csv in export/20220303-215132.
# You can go ahead with the analysis :)
#         p_id pid_type  year  \
# 1   35194431  Article  2021
# 2   35106138  Article  2021
# 3   35028636  Article  2022
# 4   34972171  Article  2021
# 5   34916929  Article  2021
# 6   34890097  Article  2021
# 7   34770684  Article  2021
# 8   34760250  Article  2021
# 9   34734333  Article  2021
# 10  34720253  Article  2021
# 11  34593888  Article  2021
# 12  34579510  Article  2021
# 13  34563332  Article  2021
# 14  34545825  Article  2021
# 15  34504584  Article  2021
# 16  34497870  Article  2021
# 17  34418958  Article  2021
# 18  34344385  Article  2021
# 19  34306613  Article  2021
# 20  34304211  Article  2021
#
#                                               journal  publisher  \
# 1   Iranian journal of pharmaceutical research : IJPR        NaN
# 2                                       F1000Research        NaN
# 3   Journal of mass spectrometry and advances in t...        NaN
# 4                                            PloS one        NaN
# 5                           Frontiers in pharmacology        NaN
# 6                                    The FEBS journal        NaN
# 7                        Sensors (Basel, Switzerland)        NaN
# 8                            Food science & nutrition        NaN
# 9                                         Protoplasma        NaN
# 10                                     Scientometrics        NaN
# 11                                 Scientific reports        NaN
# 12                Turkish journal of medical sciences        NaN
# 13                       Journal of electrocardiology        NaN
# 14       Studies in health technology and informatics        NaN
# 15              Experimental and therapeutic medicine        NaN
# 16                            PeerJ. Computer science        NaN
# 17                   BMC medical research methodology        NaN
# 18        BMC medical informatics and decision making        NaN
# 19                              Ecology and evolution        NaN
# 20                    Indian journal of ophthalmology        NaN
#
#                                                 title  book_title  \
# 1   Pharmacogenomics Implementation and Hurdles to...         NaN
# 2   Improving the support for XML dynamic updates ...         NaN
# 3   Listening to your mass spectrometer: An open-s...         NaN
# 4   Medical data integration using HL7 standards f...         NaN
# 5   Efficacy and Safety of Traditional Chinese Med...         NaN
# 6   EnzymeML-a data exchange format for biocatalys...         NaN
# 7   Control and Diagnostics System Generator for C...         NaN
# 8   The effect of curculigo orchioides (Xianmao) o...         NaN
# 9   Construction of an N6-methyladenosine lncRNA- ...         NaN
# 10  Software review: The JATSdecoder package-extra...         NaN
# 11  Evaluation of JATSdecoder as an automated text...         NaN
# 12  Could computed tomography histogram analysis a...         NaN
# 13  Computerized automated algorithm-based analyse...         NaN
# 14  ADT2FHIR - A Tool for Converting ADT/GEKID Onc...         NaN
# 15  Periplaneta americana extract ameliorates lipo...         NaN
# 16  Efficient processing of complex XSD using Hive...         NaN
# 17  Use of research electronic data capture (REDCa...         NaN
# 18  COVID term: a bilingual terminology for COVID-19.         NaN
# 19  Metadata Made Easy: Develop and Use Domain-Spe...         NaN
# 20  Intricate scientometric analysis and citation ...         NaN
#
#                                              abstract  oabstract  \
# 1   Having multiple dimensions, uncertainties and ...        NaN
# 2   Background : As the standard for the exchange ...        NaN
# 3   Introduction: We have developed a set of tools...        NaN
# 4   Integration between information systems is cri...        NaN
# 5   Background: Heart failure as an important issu...        NaN
# 6   EnzymeML is an XML-based data exchange format ...        NaN
# 7   FPGA-based data acquisition and processing sys...        NaN
# 8   The Chinese materia medica Xianmao (XM) is wid...        NaN
# 9   The present paper aims to shed light on the in...        NaN
# 10  JATSdecoder is a general toolbox which facilit...        NaN
# 11  The extraction of statistical results in scien...        NaN
# 12  BACKGROUND/AIM: To investigate the potential r...        NaN
# 13  BACKGROUND: Brugada syndrome is a rare inherit...        NaN
# 14  Harmonized and interoperable data management i...        NaN
# 15  Periplaneta americana (PA) extract acts clinic...        NaN
# 16  The eXtensible Markup Language (XML) files are...        NaN
# 17  BACKGROUND: Randomized controlled trials (RCT)...        NaN
# 18  BACKGROUND: The coronavirus disease (COVID-19)...        NaN
# 19  Metadata plays an essential role in the long-t...        NaN
# 20  Purpose: To analyze the trend of COVID-19-rela...        NaN
#
#                                               authors  editors language  \
# 1   Ayati N, Afzali M, Hasanzad M, Kebriaeezadeh A...      NaN      eng
# 2              Haw SC, Amin A, Wong CO, Subramaniam S      NaN      eng
# 3                   Pablo A, Hoofnagle AN, Mathias PC      NaN      eng
# 4                   AlQudah AA, Al-Emran M, Shaalan K      NaN      eng
# 5   Lin S, Shi Q, Ge Z, Liu Y, Cao Y, Yang Y, Zhao...      NaN      eng
# 6   Range J, Halupczok C, Lohmann J, Swainston N, ...      NaN      eng
# 7   Zabolotny WM, Guminski M, Kruszewski M, Muller...      NaN      eng
# 8   Chen L, Qu B, Wang H, Liu H, Guan Y, Zhou J, Z...      NaN      eng
# 9                                       Yu ZL, Zhu ZM      NaN      eng
# 10                                          Boschen I      NaN      eng
# 11                                          Boschen I      NaN      eng
# 12        Yurttutan N, Bilal N, Kizildag B, Doganer A      NaN      eng
# 13  Extramiana F, Laporte PL, Vaglio M, Denjoy I, ...      NaN      eng
# 14      Deppenwiese N, Delpy P, Lambarki M, Lablans M      NaN      eng
# 15                         Shi W, An L, Zhang J, Li J      NaN      eng
# 16     Martinez-Mosquera D, Navarrete R, Lujan-Mora S      NaN      eng
# 17  Kianersi S, Luetke M, Ludema C, Valenzuela A, ...      NaN      eng
# 18  Ma H, Shen L, Sun H, Xu Z, Hou L, Wu S, Fang A...      NaN      eng
# 19                                Krug RM, Petchey OL      NaN      eng
# 20                                  Kaur K, Gurnani B      NaN      eng
#
#                                             meshterms  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   [*Appointments and Schedules, Computer Securit...
# 5                                                 NaN
# 6                                                 NaN
# 7                             [*Computers, *Software]
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  [Adult, Algorithms, Anti-Arrhythmia Agents/the...
# 14  [*Data Management, *Electronic Health Records,...
# 15                                                NaN
# 16                                                NaN
# 17  [*COVID-19, Electronics, Humans, Randomized Co...
# 18  [*COVID-19, *Epidemics, Humans, Information St...
# 19                                                NaN
# 20  [*COVID-19, Humans, India/epidemiology, *Ophth...
#
#                                              keywords  \
# 1   [Developing countries, Dynamic challenges, Ira...
# 2   [XML databases, XML labeling scheme., XML-RDB ...
# 3   [Dashboard, Database, GB, Gigabyte, LC-MS/MS, ...
# 4                                                 NaN
# 5   [bayesian model, heart failure, network meta-a...
# 6   [FAIR data principles, Python, Systems Biology...
# 7   [FPGA, VHDL, Wishbone, control interface, syst...
# 8   [RT-PCR, Xianmao, kidney energy metabolism, me...
# 9   [Bioinformatics analysis, Colorectal cancer, I...
# 10  [Meta-research, PubMed central, Software, Text...
# 11                                                NaN
# 12  [Histogram analysis, cholesteatoma, computed t...
# 13  [*Brugada syndrome, *Computerized analysis, *D...
# 14  [Data Management, FHIR, Health Information Int...
# 15  [AMP-activated protein kinase, inflammation, l...
# 16  [Complex XSD, Hive, Mobile network, Performanc...
# 17  [*RCT, *REDCap, *Randomization, *Randomized co...
# 18  [*Bilingual, *COVID-19, *Medical terminology, ...
# 19                                                NaN
# 20  [*COVID-19, *COVID-19 pandemic, *Citation tren...
#
#                                                   coi  \
# 1        The authors declare no conflict of interest.
# 2              No competing interests were disclosed.
# 3   The authors declare that they have no known co...
# 4   The authors have declared that no competing in...
# 5   The authors declare that the research was cond...
# 6                                                 NaN
# 7                                                 NaN
# 8   The authors declared no potential conflicts of...
# 9                                                 NaN
# 10  Conflict of interestThe author declares no con...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15  The authors declare that they have no competin...
# 16  The authors declare there are no competing int...
# 17                                                NaN
# 18                                                NaN
# 19  The authors declare that they have no conflict...
# 20                                               None
#
#                                                 grant  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6              EXC310/Deutsche Forschungsgemeinschaft
# 7                                                 NaN
# 8                                                 NaN
# 9   81860433/National Natural Science Foundation o...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  2016YFC0901901/National Key Research and Devel...
# 19                                                NaN
# 20                                                NaN
#
#                                    doi
# 1      10.22037/ijpr.2021.114899.15091
# 2       10.12688/f1000research.69108.1
# 3         10.1016/j.jmsacl.2021.12.003
# 4         10.1371/journal.pone.0262067
# 5            10.3389/fphar.2021.659707
# 6                   10.1111/febs.16318
# 7                    10.3390/s21217378
# 8                    10.1002/fsn3.2573
# 9           10.1007/s00709-021-01718-x
# 10          10.1007/s11192-021-04162-z
# 11          10.1038/s41598-021-98782-3
# 12                 10.3906/sag-2105-12
# 13  10.1016/j.jelectrocard.2021.09.009
# 14                  10.3233/SHTI210547
# 15              10.3892/etm.2021.10572
# 16                10.7717/peerj-cs.652
# 17          10.1186/s12874-021-01362-2
# 18          10.1186/s12911-021-01593-9
# 19                   10.1002/ece3.7764
# 20              10.4103/ijo.IJO_829_21
# 'export/20220303-215132/log.txt'

# %% [markdown]
# ## Creating MedLine file
#
# Here we create a MedLine file from the entries included in the analysis. The MedLine file can then be used to import the references (and to get the papers) in reference management software, e.g. Zotero.

# %%
# Create MedLine file from the dataframe for import in reference management software
message = ("Creating MedLine file from the dataframe...")
print(message)
pids_to_get = df["p_id"].tolist()
medline_file = "medline.txt"
medline_new = open(medline_file, "w")
medline_new.close()

for x in tqdm(pids_to_get):
    x = str(x)
    pg.art_to_medline(x, medline_file)
message = ("MedLine file created.")
print(message)

destination_medline = exportdir + "/medline.txt"
copy2(medline_file, destination_medline)
# Out:
#   0%|          | 0/51 [00:00<?, ?it/s]
# Creating MedLine file from the dataframe...
# 100%|██████████| 51/51 [00:39<00:00,  1.29it/s]
# MedLine file created.
# 'export/20220303-215132/medline.txt'

# %%
# Add log
timestr = time.strftime("%Y.%m.%d-%H:%M:%S")
with open(log, "a") as f:
    f.write("paper_count_no_duplicates = " + "\"" + str(len(df)) + "\"" + "\n")
    f.write("# Data exported at: " + timestr + " to : " + exportdir + "\n")
    f.write("exportdir = " + "\"" + exportdir + "\"" + "\n")

# Copy the log file to the export folder as documentation
destination_log = exportdir + "/log.txt"
copy2(log, destination_log)
# Out:
# 'export/20220303-215132/log.txt'
